# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedAli1199/Parallel-DistibutedComputing/blob/main/PDC_A2_Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Create a script for a python plot where on x axis is "number of sequences" and on y axis is "execution time in ms". Create the lists, fill in some random values, i will add to it myself

import matplotlib.pyplot as plt
import random

# Sample data (replace with your actual data)
num_sequences = [27,99,198,396, 792 ]  # Number of sequences
execution_times = [0.384,11,40, 160, 517] # Execution times in s


plt.plot(num_sequences, execution_times, marker='o')
plt.xlabel("Number of Sequences")
plt.ylabel("Execution Time (s)")
plt.title("Execution Time vs. Number of Sequences")
plt.grid(True)
plt.show()
